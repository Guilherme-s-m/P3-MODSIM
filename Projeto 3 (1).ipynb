# %% [markdown]
# # Modelagem e simualção Projeto 3

# %% [markdown]
# Para a realização do projeto 3, escolhemos modelar um sistema mecanico, no qual simulará uma pessoa pulando de bungee jump

# %% [markdown]
# ![7fe449_97b5d19df8544f32860a2ef59ad9f654_mv2%20%281%29.webp](attachment:7fe449_97b5d19df8544f32860a2ef59ad9f654_mv2%20%281%29.webp)

# %% [markdown]
# <hr>

# %% [markdown]
# <h2>Perguntas a serem respondidas</h2>

# %% [markdown]
# <ul>
#     <li>Como seria o mesmo salto em diferentes gravidades</li>
#     <li>Como seria o mesmo salto com diferentes massas </li>
# <ul>

# %% [markdown]
# <hr>

# %% [markdown]
# <h2>Equações</h2>

# %% [markdown]
# ![Capturar.JPG](attachment:Capturar.JPG)

# %% [markdown]
# <hr>

# %% [markdown]
# <h2>Glossário</h2>

# %%
M=  #kg
G=  #m/s²
c=  #admencional
a=  #m²
V=  #m/s
K=  #N/m
X=  #m
C=  #N*s/m
m=  #

# %% [markdown]
# <hr>

# %% [markdown]
# <h2>Código</h2>

# %% [markdown]
# <h4>Bibliotecas</h4>

# %%
from math import *
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import numpy as np
